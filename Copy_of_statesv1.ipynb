# %%
import pandas as pd

# %%
df74 = pd.read_excel('.xls?raw=true','Data' )

# %%
df89 = pd.read_excel('https://github.com/pierretd/data-dump/blob/master/finance/topology/typology89.xls?raw=true','Data' )

# %%
df89.head(1)
# Out:
#    FIPS State     County name  RuralUrb93  FM  MI  ...  NS  RT  FL  CM  PV  TP
# 0  1001    AL  AUTAUGA COUNTY           2   8   8  ...   8   8   8   8   8   8
#
# [1 rows x 15 columns]

# %% [markdown]
# Lets see what Cat they both have
#
# MI
#
# GV
#
# RT-RET
#
# PV

# %%
df83 = pd.read_excel('https://github.com/pierretd/data-dump/blob/master/finance/topology/types83%20(1).xls?raw=true','Data' )

# %%
df83.head(1)
# Out:
#    FIPS               State                           County  RURALURB83  \
# 0  1001  ALABAMA             AUTAUGA                                   2
#
#    NMET  AGTP79R  MFGTP79R  MINTP79R  GVTTP79R  FEDTP79  RETTP79  POVTP79  \
# 0     1        9         9         9         9        9        9        9
#
#    UNCL79  AGTP86  MFGTP86  MINTP86  GVTTP86  UNCL86
# 0       9       9        9        9        9       9

# %%
df89 = df89.drop('FM', 1)
df89.head()
# Out:
#    FIPS State     County name  RuralUrb93  MI  MF  GV  TS  NS  RT  FL  CM  PV  \
# 0  1001    AL  AUTAUGA COUNTY           2   8   8   8   8   8   8   8   8   8
# 1  1003    AL  BALDWIN COUNTY           2   8   8   8   8   8   8   8   8   8
# 2  1005    AL  BARBOUR COUNTY           6   0   1   0   0   0   0   0   0   1
# 3  1007    AL     BIBB COUNTY           6   0   1   0   0   0   0   0   1   1
# 4  1009    AL   BLOUNT COUNTY           2   8   8   8   8   8   8   8   8   8
#
#    TP
# 0   8
# 1   8
# 2   0
# 3   0
# 4   8

# %%
df89 = df89.drop('MF', 1)
df89.head()
#TS', 'NS', 'FL', 'CM', 'TP',
# Out:
#    FIPS State     County name  RuralUrb93  MI  GV  TS  NS  RT  FL  CM  PV  TP
# 0  1001    AL  AUTAUGA COUNTY           2   8   8   8   8   8   8   8   8   8
# 1  1003    AL  BALDWIN COUNTY           2   8   8   8   8   8   8   8   8   8
# 2  1005    AL  BARBOUR COUNTY           6   0   0   0   0   0   0   0   1   0
# 3  1007    AL     BIBB COUNTY           6   0   0   0   0   0   0   1   1   0
# 4  1009    AL   BLOUNT COUNTY           2   8   8   8   8   8   8   8   8   8

# %%
df89 = df89.drop( 'NS', 1)
df89.head()
#'TS',, 'FL', 'CM', 'TP',
# Out:
#    FIPS State     County name  RuralUrb93  MI  GV  TS  RT  FL  CM  PV  TP
# 0  1001    AL  AUTAUGA COUNTY           2   8   8   8   8   8   8   8   8
# 1  1003    AL  BALDWIN COUNTY           2   8   8   8   8   8   8   8   8
# 2  1005    AL  BARBOUR COUNTY           6   0   0   0   0   0   0   1   0
# 3  1007    AL     BIBB COUNTY           6   0   0   0   0   0   1   1   0
# 4  1009    AL   BLOUNT COUNTY           2   8   8   8   8   8   8   8   8

# %%
df89 = df89.drop( 'TS', 1)
df89.head()
#'TS',, 'FL', 'CM', 'TP',
# Out:
#    FIPS State     County name  RuralUrb93  MI  GV  RT  FL  CM  PV  TP
# 0  1001    AL  AUTAUGA COUNTY           2   8   8   8   8   8   8   8
# 1  1003    AL  BALDWIN COUNTY           2   8   8   8   8   8   8   8
# 2  1005    AL  BARBOUR COUNTY           6   0   0   0   0   0   1   0
# 3  1007    AL     BIBB COUNTY           6   0   0   0   0   1   1   0
# 4  1009    AL   BLOUNT COUNTY           2   8   8   8   8   8   8   8

# %%
df89 = df89.drop( 'FL', 1)
df89.head()
#'TS',, 'FL', 'CM', 'TP',
# Out:
#    FIPS State     County name  RuralUrb93  MI  GV  RT  CM  PV  TP
# 0  1001    AL  AUTAUGA COUNTY           2   8   8   8   8   8   8
# 1  1003    AL  BALDWIN COUNTY           2   8   8   8   8   8   8
# 2  1005    AL  BARBOUR COUNTY           6   0   0   0   0   1   0
# 3  1007    AL     BIBB COUNTY           6   0   0   0   1   1   0
# 4  1009    AL   BLOUNT COUNTY           2   8   8   8   8   8   8

# %%
df89 = df89.drop( 'CM', 1)
df89.head()
#'TS',, 'FL', 'CM', 'TP',
# Out:
#    FIPS State     County name  RuralUrb93  MI  GV  RT  PV  TP
# 0  1001    AL  AUTAUGA COUNTY           2   8   8   8   8   8
# 1  1003    AL  BALDWIN COUNTY           2   8   8   8   8   8
# 2  1005    AL  BARBOUR COUNTY           6   0   0   0   1   0
# 3  1007    AL     BIBB COUNTY           6   0   0   0   1   0
# 4  1009    AL   BLOUNT COUNTY           2   8   8   8   8   8

# %%
df89 = df89.drop( 'TP', 1)
df89.head()
#'TS',, 'FL', 'CM', 'TP',
# Out:
#    FIPS State     County name  RuralUrb93  MI  GV  RT  PV
# 0  1001    AL  AUTAUGA COUNTY           2   8   8   8   8
# 1  1003    AL  BALDWIN COUNTY           2   8   8   8   8
# 2  1005    AL  BARBOUR COUNTY           6   0   0   0   1
# 3  1007    AL     BIBB COUNTY           6   0   0   0   1
# 4  1009    AL   BLOUNT COUNTY           2   8   8   8   8

# %%
df89 = df89.drop( 'GV', 1)
df89.head()
#'TS',, 'FL', 'CM', 'TP',
# Out:
#   State     County name  RT  PV
# 0    AL  AUTAUGA COUNTY   8   8
# 1    AL  BALDWIN COUNTY   8   8
# 2    AL  BARBOUR COUNTY   0   1
# 3    AL     BIBB COUNTY   0   1
# 4    AL   BLOUNT COUNTY   8   8

# %%
df89.head()
# Out:
#   State     County name  MI  GV  RT  PV
# 0    AL  AUTAUGA COUNTY   8   8   8   8
# 1    AL  BALDWIN COUNTY   8   8   8   8
# 2    AL  BARBOUR COUNTY   0   0   0   1
# 3    AL     BIBB COUNTY   0   0   0   1
# 4    AL   BLOUNT COUNTY   8   8   8   8

# %%
df83.head()
# Out:
#    FIPS               State                           County  RURALURB83  \
# 0  1001  ALABAMA             AUTAUGA                                   2
# 1  1003  ALABAMA             BALDWIN                                   2
# 2  1005  ALABAMA             BARBOUR                                   6
# 3  1007  ALABAMA             BIBB                                      6
# 4  1009  ALABAMA             BLOUNT                                    2
#
#    NMET  AGTP79R  MFGTP79R  MINTP79R  GVTTP79R  FEDTP79  RETTP79  POVTP79  \
# 0     1        9         9         9         9        9        9        9
# 1     1        9         9         9         9        9        9        9
# 2     0        0         0         0         0        0        0        1
# 3     0        0         1         0         0        0        0        0
# 4     1        9         9         9         9        9        9        9
#
#    UNCL79  AGTP86  MFGTP86  MINTP86  GVTTP86  UNCL86
# ...

# %%
cols = list(df83.columns.values)
cols
# Out:
# ['FIPS',
#  'State',
#  'County',
#  'RURALURB83',
#  'NMET',
#  'AGTP79R',
#  'MFGTP79R',
#  'MINTP79R',
#  'GVTTP79R',
#  'FEDTP79',
#  'RETTP79',
#  'POVTP79',
#  'UNCL79',
#  'AGTP86',
#  'MFGTP86',
#  'MINTP86',
#  'GVTTP86',
#  'UNCL86']

# %%
df83 = df83.drop( 'FIPS', 1)
df83.head()
# Out:
#                 State                           County  RURALURB83  NMET  \
# 0  ALABAMA             AUTAUGA                                   2     1
# 1  ALABAMA             BALDWIN                                   2     1
# 2  ALABAMA             BARBOUR                                   6     0
# 3  ALABAMA             BIBB                                      6     0
# 4  ALABAMA             BLOUNT                                    2     1
#
#    AGTP79R  MFGTP79R  MINTP79R  GVTTP79R  FEDTP79  RETTP79  POVTP79  UNCL79  \
# 0        9         9         9         9        9        9        9       9
# 1        9         9         9         9        9        9        9       9
# 2        0         0         0         0        0        0        1       0
# 3        0         1         0         0        0        0        0       0
# 4        9         9         9         9        9        9        9       9
#
#    AGTP86  MFGTP86  MINTP86  GVTTP86  UNCL86
# ...

# %% [markdown]
#  'State',
#  'County',
#  'RURALURB83',
#  'NMET',
#  'AGTP79R',
#  'MFGTP79R',
#  '**MINTP79R**',
#  '**GVTTP79R**',
#  'FEDTP79',
#  '**RETTP79**',
#  '**POVTP79**',
#  'UNCL79',
#  'AGTP86',
#  'MFGTP86',
#  'MINTP86',
#  'GVTTP86',
#  'UNCL86'

# %%
df83 = df83.drop( 
 'RURALURB83', 1)
df83.head()
# Out:
#                 State                           County  NMET  AGTP79R  \
# 0  ALABAMA             AUTAUGA                             1        9
# 1  ALABAMA             BALDWIN                             1        9
# 2  ALABAMA             BARBOUR                             0        0
# 3  ALABAMA             BIBB                                0        0
# 4  ALABAMA             BLOUNT                              1        9
#
#    MFGTP79R  MINTP79R  GVTTP79R  FEDTP79  RETTP79  POVTP79  UNCL79  AGTP86  \
# 0         9         9         9        9        9        9       9       9
# 1         9         9         9        9        9        9       9       9
# 2         0         0         0        0        0        1       0       0
# 3         1         0         0        0        0        0       0       0
# 4         9         9         9        9        9        9       9       9
#
#    MFGTP86  MINTP86  GVTTP86  UNCL86
# 0        9        9        9       9
# ...

# %%
df83 = df83.drop( 'NMET', 1)
df83.head()
# Out:
#                 State                           County  AGTP79R  MFGTP79R  \
# 0  ALABAMA             AUTAUGA                                9         9
# 1  ALABAMA             BALDWIN                                9         9
# 2  ALABAMA             BARBOUR                                0         0
# 3  ALABAMA             BIBB                                   0         1
# 4  ALABAMA             BLOUNT                                 9         9
#
#    MINTP79R  GVTTP79R  FEDTP79  RETTP79  POVTP79  UNCL79  AGTP86  MFGTP86  \
# 0         9         9        9        9        9       9       9        9
# 1         9         9        9        9        9       9       9        9
# 2         0         0        0        0        1       0       0        1
# 3         0         0        0        0        0       0       0        1
# 4         9         9        9        9        9       9       9        9
#
#    MINTP86  GVTTP86
# 0        9        9
# 1        9        9
# ...

# %%
df83 = df83.drop( 'AGTP79R', 1)
df83.head()
# Out:
#                 State                           County  MFGTP79R  MINTP79R  \
# 0  ALABAMA             AUTAUGA                                 9         9
# 1  ALABAMA             BALDWIN                                 9         9
# 2  ALABAMA             BARBOUR                                 0         0
# 3  ALABAMA             BIBB                                    1         0
# 4  ALABAMA             BLOUNT                                  9         9
#
#    GVTTP79R  FEDTP79  RETTP79  POVTP79  UNCL79  AGTP86  MFGTP86  MINTP86  \
# 0         9        9        9        9       9       9        9        9
# 1         9        9        9        9       9       9        9        9
# 2         0        0        0        1       0       0        1        0
# 3         0        0        0        0       0       0        1        0
# 4         9        9        9        9       9       9        9        9
#
#    GVTTP86
# 0        9
# 1        9
# 2        0
# 3        0
# 4        9

# %%
df83 = df83.drop( 'MFGTP86', 1)
df83.head()
# Out:
#                 State                           County  MINTP79R  GVTTP79R  \
# 0  ALABAMA             AUTAUGA                                 9         9
# 1  ALABAMA             BALDWIN                                 9         9
# 2  ALABAMA             BARBOUR                                 0         0
# 3  ALABAMA             BIBB                                    0         0
# 4  ALABAMA             BLOUNT                                  9         9
#
#    RETTP79  POVTP79  MINTP86  GVTTP86
# 0        9        9        9        9
# 1        9        9        9        9
# 2        0        1        0        0
# 3        0        0        0        0
# 4        9        9        9        9

# %%
df83 = df83.drop( 'FEDTP79', 1)
df83.head()
# Out:
#                 State                           County  MINTP79R  GVTTP79R  \
# 0  ALABAMA             AUTAUGA                                 9         9
# 1  ALABAMA             BALDWIN                                 9         9
# 2  ALABAMA             BARBOUR                                 0         0
# 3  ALABAMA             BIBB                                    0         0
# 4  ALABAMA             BLOUNT                                  9         9
#
#    RETTP79  POVTP79  UNCL79  AGTP86  MFGTP86  MINTP86  GVTTP86
# 0        9        9       9       9        9        9        9
# 1        9        9       9       9        9        9        9
# 2        0        1       0       0        1        0        0
# 3        0        0       0       0        1        0        0
# 4        9        9       9       9        9        9        9

# %%
df83 = df83.drop( 'UNCL79', 1)
df83.head()
# Out:
#                 State                           County  MINTP79R  GVTTP79R  \
# 0  ALABAMA             AUTAUGA                                 9         9
# 1  ALABAMA             BALDWIN                                 9         9
# 2  ALABAMA             BARBOUR                                 0         0
# 3  ALABAMA             BIBB                                    0         0
# 4  ALABAMA             BLOUNT                                  9         9
#
#    RETTP79  POVTP79  AGTP86  MFGTP86  MINTP86  GVTTP86
# 0        9        9       9        9        9        9
# 1        9        9       9        9        9        9
# 2        0        1       0        1        0        0
# 3        0        0       0        1        0        0
# 4        9        9       9        9        9        9

# %%
df83 = df83.drop( 'MINTP86', 1)
df83.head()
# Out:
#                 State                           County  GVTTP79R  RETTP79  \
# 0  ALABAMA             AUTAUGA                                 9        9
# 1  ALABAMA             BALDWIN                                 9        9
# 2  ALABAMA             BARBOUR                                 0        0
# 3  ALABAMA             BIBB                                    0        0
# 4  ALABAMA             BLOUNT                                  9        9
#
#    POVTP79  GVTTP86
# 0        9        9
# 1        9        9
# 2        1        0
# 3        0        0
# 4        9        9

# %%
df83 = df83.drop( 'GVTTP86', 1)
df83.head()
# Out:
#                 State                           County  RETTP79  POVTP79
# 0  ALABAMA             AUTAUGA                                9        9
# 1  ALABAMA             BALDWIN                                9        9
# 2  ALABAMA             BARBOUR                                0        1
# 3  ALABAMA             BIBB                                   0        0
# 4  ALABAMA             BLOUNT                                 9        9

# %%
df83.head()
# Out:
#                 State                           County  MINTP79R  GVTTP79R  \
# 0  ALABAMA             AUTAUGA                                 9         9
# 1  ALABAMA             BALDWIN                                 9         9
# 2  ALABAMA             BARBOUR                                 0         0
# 3  ALABAMA             BIBB                                    0         0
# 4  ALABAMA             BLOUNT                                  9         9
#
#    RETTP79  POVTP79  MINTP86  GVTTP86
# 0        9        9        9        9
# 1        9        9        9        9
# 2        0        1        0        0
# 3        0        0        0        0
# 4        9        9        9        9

# %%
df89['Year']= '1989'
df83['Year']= '1983'

# %%
df89.head()
# Out:
#   State     County name  RT  PV  Year
# 0    AL  AUTAUGA COUNTY   8   8  1989
# 1    AL  BALDWIN COUNTY   8   8  1989
# 2    AL  BARBOUR COUNTY   0   1  1989
# 3    AL     BIBB COUNTY   0   1  1989
# 4    AL   BLOUNT COUNTY   8   8  1989

# %%
group89 = df89.groupby(by='State').mean()

# %%
group83 = df83.groupby(by='State').mean()

# %%
group89['Year']= '1989'
group83['Year']= '1983'
group89
# Out:
#              RT        PV  Year
# State
# AK     0.642857  0.785714  1989
# AL     2.507463  2.865672  1989
# AR     1.266667  1.586667  1989
# AZ     3.000000  2.866667  1989
# CA     4.879310  4.689655  1989
# CO     1.428571  1.380952  1989
# CT     6.000000  6.000000  1989
# DC     8.000000  8.000000  1989
# DE     5.666667  5.333333  1989
# FL     4.343284  4.238806  1989
# GA     2.169811  2.515723  1989
# HI     2.750000  2.000000  1989
# IA     0.808081  0.808081  1989
# ID     0.409091  0.386364  1989
# IL     2.196078  2.235294  1989
# IN     3.217391  3.217391  1989
# KS     0.685714  0.685714  1989
# KY     1.475000  1.916667  1989
# LA     3.000000  3.515625  1989
# MA     6.357143  6.285714  1989
# MD     5.083333  5.000000  1989
# ME     1.562500  1.500000  1989
# MI     2.590361  2.421687  1989
# MN     1.666667  1.678161  1989
# MO     1.600000  1.756522  1989
# MS     0.682927  1.439024  1989
# MT     0.339286  0.339286  1989
# NC     2.970000  2.990000  1989
# ...

# %%
group83
# Out:
#                      RETTP79   POVTP79  Year
# State
#                     9.000000  9.000000  1983
# ALABAMA             2.611940  2.820896  1983
# ARIZONA             2.000000  1.384615  1983
# ARIZONA 14/         1.000000  0.000000  1983
# ARKANSAS            1.653333  1.373333  1983
# CALIFORNIA          5.034483  4.810345  1983
# COLORADO            1.555556  1.444444  1983
# CONNECTICUT         6.750000  6.750000  1983
# DELAWARE            3.666667  3.000000  1983
# FLORIDA             4.582090  4.253731  1983
# GEORGIA             2.289308  2.320755  1983
# IDAHO               0.000000  0.000000  1983
# IDAHO               0.418605  0.209302  1983
# ILLINOIS            2.333333  2.313725  1983
# INDIANA             2.989130  2.934783  1983
# IOWA                1.000000  1.000000  1983
# KANSAS              0.733333  0.685714  1983
# KENTUCKY            1.541667  1.700000  1983
# LOUISIANA           2.734375  2.812500  1983
# MAINE               2.000000  1.687500  1983
# ...

# %%
cols = list(df89.State.values)
cols
# Out:
# ['AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AL',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AZ',
#  'AZ',
#  'AZ',
#  'AZ',
#  'AZ',
#  'AZ',
#  'AZ',
#  'AZ',
#  'AZ',
#  'AZ',
#  'AZ',
#  'AZ',
#  'AZ',
#  'AZ',
#  'AZ',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/pierretd/data-dump/master/finance/topology/8389%20-%20Sheet1.csv')

# %%
df.head()
# Out:
#   State   RETTP79   POVTP79  Year
# 0    AK  2.611940  2.820896  1983
# 1    AL  2.000000  1.384615  1983
# 2    AR  1.000000  0.000000  1983
# 3    AZ  1.653333  1.373333  1983
# 4    CA  5.034483  4.810345  1983

# %%
df.groupby(by='State')['RETTP79'].mean().plot(kind='bar');
